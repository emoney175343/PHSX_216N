# %% [markdown]
# <a href="https://colab.research.google.com/github/emoney175343/PHSX_216N/blob/main/Slow_RC_Discharging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

Vd = np.array([11.44, 7.25, 4.562, 2.982, 1.854, 1.181, 0.755, 0.491, 0.318, 0.208, 0.140, 0.093, 0.064]) # y label
t = np.array ([0, 10.04, 20.09, 30.13, 40.05, 50.13, 60.19, 69.97, 80.11, 90.05, 99.97, 110.03, 120.19]) # x label

plt.plot(t,Vd)

x = t
y = Vd

plot_title= 'Charging Voltage v.s Time'
x_label= 't (s)'
y_label= 'Vd (V)'

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
# Out:
# Text(0.5, 1.0, 'Charging Voltage v.s Time')
